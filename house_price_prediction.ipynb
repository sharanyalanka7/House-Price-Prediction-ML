# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('house-prices.csv')
X = df.iloc[:,0:1]
y = df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
plt.scatter(X_test,y_test,color = 'pink')
plt.plot(X_test,y_pred,color='red')
plt.show()
print(lr.coef_)
print(lr.intercept_)
areas = [[1000],[2000],[3000]]

predictions = lr.predict(areas)
print(predictions)
comparison = pd.DataFrame({
    "Actual Price": y_test,
    "Predicted Price": y_pred
})

print(comparison)
# Out:
# [96.14550455]
# 61136.52754575596
# [157282.03209297 253427.53664019 349573.04118741]
#      Actual Price  Predicted Price
# 27      260242.67    197855.435012
# 396     279002.49    341304.527796
# 116     380317.42    442834.180598
# 276     196061.08    282944.206536
# 839     468291.84    409760.127034
# ..            ...              ...
# 330     345811.58    350919.078251
# 348     541245.42    480042.490858
# 175     558848.82    420816.860057
# 33      169397.15    276983.185254
# 271     324897.70    163819.926402
#
# [250 rows x 2 columns]
# c:\Users\Sharanya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
